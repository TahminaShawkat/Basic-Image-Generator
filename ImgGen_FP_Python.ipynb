# %%
from google.colab import drive
drive.mount('/content/gdrive')

import sys
sys.path.append('/content/gdrive/MyDrive/Colab Notebooks/Python in MNCLT')

import os
os.chdir('/content/gdrive/MyDrive/Colab Notebooks/Python in MNCLT')
# Out:
# Mounted at /content/gdrive

# %%
#Module
#Libraries
from google.colab.patches import cv2_imshow
from matplotlib import*
import skimage.filters
import cv2
from matplotlib import image              #Matplotlib is a low level graph plotting library in python that serves as a visualization utility.
from matplotlib import pyplot as plt      #pyplot is the submodule,usually importer under the plt alias
import numpy as np 

#Functions
# code for displaying multiple images in one figure 

def flowerList(flowers):
  fig = plt.figure(figsize=(15, 10))                # create figure
  rows = 1                                          # setting values to rows and column variables
  columns = 5
  #rows, colums = 1,5
  # reading images
  fl1 = image.imread('white rose.jpg')
  fl2 = image.imread('1 white-cosmos.jpg')
  fl3 = image.imread('1 white-jasmine.jpg')
  fl4 = image.imread('1 white-tulip.jpg')
  fl5 = image.imread('1 white-orchid.jpg')
  
  fig.add_subplot(rows, columns, 1)                     # Adds a subplot at the 1st position
  plt.imshow(fl1)                                       # showing image
  plt.axis('off')
  plt.title("Rose")
  
  fig.add_subplot(rows, columns, 2)                     # Adds a subplot at the 2nd position
  plt.imshow(fl2)
  plt.axis('off')
  plt.title("Cosmos")
  
  fig.add_subplot(rows, columns, 3)                     # Adds a subplot at the 3rd position
  plt.imshow(fl3)
  plt.axis('off')
  plt.title("Jasmine")
  
  fig.add_subplot(rows, columns, 4)                     # Adds a subplot at the 4th position
  plt.imshow(fl4)
  plt.axis('off')
  plt.title("Tulip")

  fig.add_subplot(rows, columns, 5)                     # Adds a subplot at the 4th position
  plt.imshow(fl5)
  plt.axis('off')
  plt.title("Orchid") 

  plt.show()                                         #plt.show() is showing the pictures after catagory
  plt.waitforbuttonpress(1)

def flower_select(flowers):
  #fig = plt.figure(figsize=(3, 5))                # create figure
  plt.axis('off')
 # reading images

  fl1 = image.imread('white rose.jpg')
  fl2 = image.imread('1 white-cosmos.jpg')
  fl3 = image.imread('1 white-jasmine.jpg')
  fl4 = image.imread('1 white-tulip.jpg')
  fl5 = image.imread('1 white-orchid.jpg')

  if flowers=='Rose🌹':
    plt.imshow(fl1)
    plt.show()
    return fl1
  elif flowers=='Cosmos🌺':
    plt.imshow(fl2)
    plt.show()
    return fl2
  elif flowers=='Jasmine🌸':
    plt.imshow(fl3)
    plt.show()
    return fl3
  elif flowers=='Tulip🌷':
    plt.imshow(fl4)
    plt.show()
    return fl4
  elif flowers=='Orchid🥀':
    plt.imshow(fl5)
    plt.show()
    return fl5
  else:
    print('No flower selected')
  #plt.show()
  #plt.waitforbuttonpress(1)

  #-----------Fruits----------------
def fruitList(fruits) :
  fig = plt.figure(figsize=(15, 10))                # create figure
  rows = 1                                          # setting values to rows and column variables
  columns = 5
# reading images
  fr1 = image.imread('ys banana.jpg')
  fr2 = image.imread('white-orange.jpg')
  fr3 = image.imread('1 white-strawberry.jpg')
  fr4 = image.imread('white apple.jpg')
   
  fig.add_subplot(rows, columns, 1)                    # Adds a subplot at the 1st position
  plt.imshow(fr1)                                    # showing image
  plt.axis('off')
  plt.title("Banana")
    
  fig.add_subplot(rows, columns, 2)                     # Adds a subplot at the 2nd position
  plt.imshow(fr2)
  plt.axis('off')
  plt.title(" Orange")
    
  fig.add_subplot(rows, columns, 3)                     # Adds a subplot at the 3rd position
  plt.imshow(fr3)
  plt.axis('off')
  plt.title("Strawberry")
    
  fig.add_subplot(rows, columns, 4)                     # Adds a subplot at the 4th position
  plt.imshow(fr4)
  plt.axis('off')
  plt.title("Apple")
    
  plt.show()                                            #plt.show() is showing the pictures after catagory
  plt.waitforbuttonpress(1)

def fruit_select(fruits):
  #fig = plt.figure(figsize=(3, 5))                      # create figure
  plt.axis('off')
# reading images
  fr1 = image.imread('ys banana.jpg')
  fr2 = image.imread('white-orange.jpg')
  fr3 = image.imread('1 white-strawberry.jpg')
  fr4 = image.imread('white apple.jpg')
  
  if fruits == 'Banana🍌':
    plt.imshow(fr1)
    plt.show()
    return fr1
  elif fruits == 'Orange🍊':
    plt.imshow(fr2)
    plt.show()
    return fr2
  elif fruits == 'Strawberry🍓':
    plt.imshow(fr3)
    plt.show()
    return fr3
  elif fruits == 'Apple🍎':
    plt.imshow(fr4)
    plt.show()
    return fr4
  else:
    print('No fruit selected')
  #plt.show()
  #plt.waitforbuttonpress(1)

#-----------pets----------------
def petList(pets):
  fig = plt.figure(figsize=(15, 10))                # create figure
  rows = 1                                          # setting values to rows and column variables
  columns = 6
  # reading images
  pt1 = image.imread('1 kitty.jfif')
  pt2 = image.imread('2 kitty.webp')
  pt3 = image.imread('3 kitty.jpg')
  pt4 = image.imread('1 puppy.jpg')
  pt5 = image.imread('2 puppy.jpg')
  pt6 = image.imread('3 puppy.jpg')
  
  fig.add_subplot(rows, columns, 1)                    # Adds a subplot at the 1st position
  plt.imshow(pt1)                                    # showing image
  plt.axis('off')
  plt.title('Kitty 1')
  
  fig.add_subplot(rows, columns, 2)                     # Adds a subplot at the 2nd position
  plt.imshow(pt2)
  plt.axis('off')
  plt.title('Kitty 2')
  
  fig.add_subplot(rows, columns, 3)                     # Adds a subplot at the 3rd position
  plt.imshow(pt3)
  plt.axis('off')
  plt.title('Kitty 2')
  
  fig.add_subplot(rows, columns, 4)                     # Adds a subplot at the 4th position
  plt.imshow(pt4)
  plt.axis('off')
  plt.title('Puppy 1')

  fig.add_subplot(rows, columns, 5)                     # Adds a subplot at the 5th position
  plt.imshow(pt5)
  plt.axis('off')
  plt.title('Puppy 2')

  fig.add_subplot(rows, columns, 6)                     # Adds a subplot at the 6th position
  plt.imshow(pt6)
  plt.axis('off')
  plt.title('Puppy 3')
  
  plt.show()                                             #plt.show() is showing the pictures after catagory
  plt.waitforbuttonpress(1)

def pet_select(pets):                                    # this def pet_select(pets): is using to select pets pictures from the album
  #fig = plt.figure(figsize=(3, 5))                      # create figure
  plt.axis('off')
 # reading images
  pt1 = image.imread('1 kitty.jfif')
  pt2 = image.imread('2 kitty.webp')
  pt3 = image.imread('3 kitty.jpg')
  pt4 = image.imread('1 puppy.jpg')
  pt5 = image.imread('2 puppy.jpg')
  pt6 = image.imread('3 puppy.jpg')

  if pets=='Kitty 1':
    plt.imshow(pt1)
    plt.show()
    return pt1
  elif pets == 'Kitty 2':
    plt.imshow(pt2)
    plt.show() 
    return pt2
  elif pets == 'Kitty 3':
    plt.imshow(pt3)
    plt.show()
    return pt3
  elif pets == 'Puppy 1': 
    plt.imshow(pt4)
    plt.show()
    return pt4
  elif pets == 'Puppy 2':
    plt.imshow(pt5) 
    plt.show()
    return pt5
  elif pets == 'Puppy 3':
    plt.imshow(pt6)
    plt.show()
    return pt6
  else:
    print('No pet selected')
  #plt.show()
  #plt.waitforbuttonpress(2)
#-----------colors----------------
def blue(img1):
  img = img1.copy()
  img[:,:,0] = img[:,:,0]*0.0
  img[:,:,0] = img[:,:,0]*0.2
  img[:,:,1] = img[:,:,1]*0.775
  return img

def pink(img1):
  img = img1.copy()
  img[:,:,0] = img[:,:,0]*0.255
  img[:,:,1] = img[:,:,1]*0.105
  img[:,:,2] = img[:,:,2]*0.180
  return img

def orange(img1):
  img = img1.copy()
  img[:,:,0] = img[:,:,0]*0.85
  img[:,:,1] = img[:,:,1]*0.425
  img[:,:,2] = img[:,:,2]*0.150
  return img

def yellow(img1):
  img = img1.copy()
  img[:,:,0] = img[:,:,0]*0.320
  img[:,:,1] = img[:,:,1]*0.650
  img[:,:,2] = img[:,:,2]*0.350
  return img

def red(img1):
  img = img1.copy()
  img[:,:,0] = img[:,:,0]*0.95
  img[:,:,1] = img[:,:,1]*0.1
  img[:,:,2] = img[:,:,2]*0.0
  return img

def purple(img1):
  img = img1.copy()
  img[:,:,0] = img[:,:,0]*0.60
  img[:,:,1] = img[:,:,1]*0
  img[:,:,2] = img[:,:,2]*0
  return img

def green(img1):
  img = img1.copy()
  img[:,:,0] = img[:,:,0]*0.0
  img[:,:,1] = img[:,:,1]*0.900
  img[:,:,2] = img[:,:,2]*0.55
  return img
#-------------EFFECTS----------------
def blur_image(img1):
  img = img1.copy() 
  blur = cv2.blur(img,(15,10))
  imgDisp = np.concatenate((img, blur), axis=1)
  #cv2_imshow(imgDisp)
  cv2.resize(img, (100,100))
  img_45 = cv2.resize(imgDisp, None, fx = 0.45, fy = 0.45)
  cv2_imshow(img_45)
  return img

def pencilSketch_image(img1):
  img = img1.copy()
  s, sketch = cv2.pencilSketch(img, shade_factor = 0.07)
  imgDisp = np.concatenate((img, sketch), axis=1)
  #cv2_imshow(imgDisp)
  cv2.resize(img, (100,100))
  img_45 = cv2.resize(imgDisp, None, fx = 0.45, fy = 0.45)
  cv2_imshow(img_45)
  return img
  
def stylization_image(img1):
  img = img1.copy()
  styled = cv2.stylization(img, sigma_s=100, sigma_r=0.7)
  imgDisp = np.concatenate((img, styled), axis=1)
  #cv2_imshow(imgDisp)
  cv2.resize(img, (100,100))
  img_45 = cv2.resize(imgDisp, None, fx = 0.45, fy = 0.45)                      #img_45 is varialbe where the resized image is saved
  cv2_imshow(img_45)
  return img

# %%
#main code
#from streamlit_image_select import image_select

print('***Basic Image Generator***\n***Welcome & Lets Start***\n')

# list of catagory/album & items/photos
List_item = ['Flowers🌹', 'Fruits🍍', 'Pets🐾']                       
flowers = ['Rose🌹','Cosmos🌺', 'Jasmine🌸', 'Tulip🌷','Orchid🥀']
fruits = ['Banana🍌', 'Orange🍊','Strawberry🍓','Apple🍎']
pets = ['Kitty 1','Kitty 2','Kitty 3','Puppy 1','Puppy 2','Puppy 3'] 
colors = ['Blue🔵','Pink🟣','Orange🟠','Yellow🟡','Red🔴','Green🟢']
effects =['Blur 🕶','Pencil Sketch ✏','Stylization 🖼']
user_input = flower_input = fruit_input = pet_input = color_input = effects_input = chosen_item = ''      #variable decleration for user input
text=''
#----select category----:
while text !='n':
  #print('Categories are:',List_item) 
  user_input = ''
  input_txt = 'Select Item from Category📋:\n'
  for index, item in enumerate(List_item):                                      #enumerate(): using for iteration item in list
    input_txt += f'{index+1}) {item}\n'                                         #including expressions inside of a string by prefixing the string with f'' expression.
  input_txt += 'Your choice: '
  while user_input not in map(str, range(1, len(List_item) + 1)):               #map() for iteration items from lists starting from number 1 which is not in list
    user_input = input(input_txt)   
    if user_input.isnumeric():
      if int(user_input) < len(List_item)+1 :                                                 #isnumeric() checking for numeric input by user
        print('You picked: ' + List_item[int(user_input) - 1])                    #int(user_input): to select the catagory with numbers,List_item() calling items from catagory  
      else:
        print('Value out of range.')
    else:
      print('---Numeric Value Expected---/you input out of range')
  choice1 = List_item[int(user_input) - 1] 
  choice_msg = 'Select your '+choice1+' option:\n'

#****selected and picture list showed****

#***********CALL IMAGE***********
#----Flowers----
  flower_input=''
  if choice1 == 'Flowers🌹':
    flowerList(flowers) 
    for index, item_flower in enumerate(flowers):                               #enumerate(): 
      choice_msg += f'{index+1}) {item_flower}\n'
    choice_msg += 'Your choice: '  
    while flower_input not in map(str, range(1, len(flowers) + 1)):
      flower_input = input(choice_msg) 
      if flower_input.isnumeric():
        if int(flower_input) < len(flowers)+1 :
          print('You picked: ' + flowers[int(flower_input) - 1])                #flower_input: selecting photos from the list by numbers,flowers() calling flowers items from list
        else:
          print('Value out of range.')
      else:
        print('---Numeric Value Expected---')  
      #print('You picked: ' + flowers[int(flower_input) - 1]) 
    chosen_item = flower_select(flowers[int(flower_input) - 1])                 #flower_select() used to select fruit photos from list

#----Fruits----
  fruit_input=''
  if choice1 == 'Fruits🍍':
    fruitList(fruits)  
    for index, item_fruit in enumerate(fruits):                                 #enumerate(): 
      choice_msg += f'{index+1}) {item_fruit}\n'
    choice_msg += 'Your choice: '
    while fruit_input not in map(str, range(1, len(fruits) + 1)):               #map() for iteration itm
      fruit_input = input(choice_msg) 
      if fruit_input.isnumeric():
        if int(fruit_input) < len(fruits)+1 :
          print('You picked: ' + fruits[int(fruit_input) - 1])                    #fruit_input: selecting photos from the list by numbers,fruits() calling flowers items from list  
        else:
          print('Value out of range.')
      else:
        print('---Numeric Value Expected---')
      #print('You picked: ' + fruits[int(fruit_input) - 1])
    chosen_item = fruit_select(fruits[int(fruit_input) - 1])                    #fruit_select() used to select fruit photos from list

#----Pets----
  pet_input=''
  if choice1 == 'Pets🐾': 
    petList(pets)
    for index, item_pet in enumerate(pets):                                     #enumerate(): 
      choice_msg += f'{index+1}) {item_pet}\n'
    choice_msg += 'Your choice: '
    while pet_input not in map(str, range(1, len(pets) + 1)):                   
      pet_input = input(choice_msg) 
      if pet_input.isnumeric():
        if int(pet_input) < len(pets)+1 :
          print('You picked: ' + pets[int(pet_input) - 1])                        #pet_input: selecting photos from the list by numbers,pets() calling pet items from list  
        else:
          print('Value out of range.')
      else:
        print('---Numeric Value Expected---')
      #print('You picked: ' + pets[int(pet_input) - 1])
    chosen_item = pet_select(pets[int(pet_input) - 1])                          #pet_select() used to select fruit photos from list
#***********CALL EFFECTS/COLOR***********
    #**********CHOOSE COLOR***********
  
  choice_color_msg='Choose the Color: \n'
  color_input=''
  for index, item_color in enumerate(colors):                                   #enumerate(): 
    choice_color_msg += f'{index+1}) {item_color}\n' 
  choice_color_msg += 'Your choice: '
  while color_input not in map(str, range(1, len(colors) + 1)):
    color_input = input(choice_color_msg) 
    if color_input.isnumeric():
      if int(color_input) < len(colors)+1 :
        print('You picked: ' + colors[int(color_input) - 1])                      #int(user_input): to select the catagory with numbers  
      else:
        print('Value out of range.')
    else:
      print('---Numeric Value Expected---') 
  #print('You picked: ' + colors[int(color_input) - 1])

  #**********CHOOSE COLOR condition loop***********                             # using this condition to check,selelct, use colors from the list
  print()
  check_color=(colors[int(color_input) - 1])
  plt.axis('off')
  if check_color == 'Blue🔵':
    imgA=blue(chosen_item)                                                      #blue()
    plt.imshow(imgA)
    plt.show()
  elif check_color == 'Pink🟣':                                                   #pink()
    imgA=pink(chosen_item)
    plt.imshow(imgA)
    plt.show()
  elif check_color == 'Orange🟠':
    imgA=orange(chosen_item)                                                    #orange()
    plt.imshow(imgA)
    plt.show()
  elif check_color == 'Yellow🟡':                                                 #yellow()
    imgA=yellow(chosen_item)
    plt.imshow(imgA)
    plt.show()
  elif check_color == 'Red🔴':
    imgA=red(chosen_item)                                                       #red()
    plt.imshow(imgA)
    plt.show()
  elif check_color == 'Green🟢':
    imgA=green(chosen_item)                                                       #red()
    plt.imshow(imgA)
    plt.show()
  else:
    print('Color not choosen')
#**********CHOOSE EFFECTS***********
  print()
  choice_effect_msg='Choose the Effects: \n'
  effects_input=''
  for index, item_effect in enumerate(effects):                                 #enumerate(): 
    choice_effect_msg += f'{index+1}) {item_effect}\n' 
  choice_effect_msg += 'Your choice: '
  while effects_input not in map(str, range(1, len(effects) + 1)):
    effects_input = input(choice_effect_msg)  
    if effects_input.isnumeric():
      if int(effects_input) < len(effects)+1 :
        print('You picked: ' + effects[int(effects_input) - 1])                   #effects() selecting effects from list    
      else:
        print('Value out of range.')
    else:
      print('---Numeric Value Expected---')
  #print('You picked: ' + effects[int(effects_input) - 1])
  
  #**********CHOOSE EFFECTS condition loop***********
  print()
  check_effect=(effects[int(effects_input) - 1])
  #plt.axis('off')
  if check_effect == 'Blur 🕶':
    imgA=blur_image(chosen_item)     
  elif check_effect == 'Pencil Sketch ✏':
    imgA=pencilSketch_image(chosen_item)
  elif check_effect == 'Stylization 🖼':
    imgA=stylization_image(chosen_item)
    #plt.imshow(imgA)
    #plt.show()
  else:
    print('Effects not choosen')
#************************************* 

#**********Checking values True or False***********
  text= True
  while text== True:
    text = input('Do you want to continue? \nType y for Yes or n for No:\n') 
    if text.isnumeric()==True:
      print('Numbers not Allowed')
      text= True
      continue
  while text !='n' and text!='y':
    text = input('Type y or n:\n')
    if text.isnumeric()==True:
      print('Numbers not Allowed')
      text= True
      continue
  if text=='y':
    #print(text)
    continue
  else:
    print('Thank you!')
    break
#******Generating Report******
print()
fname = 'Report_ImgGen_FP_Python.txt'
with open('Report_ImgGen_FP_Python.txt') as fObject:                            ### with + open are keywords. fObject is a variable
  #print(type(file_object))
  contents = fObject.read() 
  print(contents)
with open(fname, 'a') as fObject:
  fObject.write('\n')
  print('Leave your feedback:\n')
  fObject.write(input())
# Out:
# ***Basic Image Generator***
# ***Welcome & Lets Start***
#
# Select Item from Category📋:
# 1) Flowers🌹
# 2) Fruits🍍
# 3) Pets🐾
# Your choice: 2
# You picked: Fruits🍍
# Select your Fruits🍍 option:
# 1) Banana🍌
# 2) Orange🍊
# 3) Strawberry🍓
# 4) Apple🍎
# Your choice: 2
# You picked: Orange🍊
# Choose the Color:
# 1) Blue🔵
# 2) Pink🟣
# 3) Orange🟠
# 4) Yellow🟡
# 5) Red🔴
# 6) Green🟢
# Your choice: 1
# You picked: Blue🔵
# Choose the Effects:
# 1) Blur 🕶
# 2) Pencil Sketch ✏
# 3) Stylization 🖼
# Your choice: 3
# You picked: Stylization 🖼
# <PIL.Image.Image image mode=RGB size=563x260 at 0x7F2C1E6EAB20>
# Do you want to continue?
# Type y for Yes or n for No:
# n
# Thank you!
#
# **--Report--**
#
# Thanks for using this app. More fetaures are on the way.
# Stay connected
#
#
#
# I enjoyed using this app
# Leave your feedback:
#
# Looking for more features!

# %%
2
1111
213This is instruction from Hareem:1) Download Anaconda from here: https://www.anaconda.com/
2) Install on your computer as  a desktop app
3) Open Anaconda Navigator
4) Install Spyder (which is an easy to use IDE)




List starts from  position. that is why using +1 to start positioning from 1

#catching error for different user input and colors
chosen_flower = flower_select(flowers[int(flower_input) - 1])
#img2=blue(chosen_flower)
#plt.imshow(img2)
#plt.show()

# %%
#!curl -o logo.png https://colab.research.google.com/img/colab_favicon_256px.png
#import cv2
#img = cv2.imread('logo.png', cv2.IMREAD_UNCHANGED)
#cv2_imshow(img)
#----------------------------------------------------------------------------
from google.colab.patches import cv2_imshow
from matplotlib import*
import skimage.filters
import cv2
from matplotlib import image              #Matplotlib is a low level graph plotting library in python that serves as a visualization utility.
from matplotlib import pyplot as plt      #pyplot is the submodule,usually importer under the plt alias
import numpy as np 

#read image


#color code img = image.imread("white rose.jpg")
#img = image.imread('1 white-tulip.jpg')
#img1 = img.copy()
#img1[:,:,0] = img1[:,:,0]*0.0
#img1[:,:,1] = img1[:,:,1]*0.392
#img1[:,:,2] = img1[:,:,2]*0.203
#pp.axis('off')

#****figure*****
#fig = plt.figure()
#r,c=1,2
#f1 = fig.add_subplot(r,c,1)
#f1.imshow(img)
#f1 = fig.add_subplot(r,c,2)
#f1.imshow(img1)

#******
#blur = image.blur(img,(5,5)) 
#s, sketch = image.pencilSketch(img, shade_factor = 0.07)
#s, sketch = image
#styled = image.stylization(img, sigma_s=100, sigma_r=0.4)
#imgDisp = np.concatenate((img, blur, sketch, styled), axis=1)
#cv2_imshow(imgDisp)
#from matplotlib import*
#pp.imshow(s, cmap="gray")
####################3
#A = np.random.rand(5,5)
#pp.pcolor(A)
#pp.figure(figsize=(5,5))
#pp.imshow(img, cmap="gray")
#def blur(img):
 # for i in range(1,img.shape[0]-1):
  #  for j in range(1,img.shape[1]-1): 
   #   img[i,j] = (40*img[i,j] + img[i-1,j] + img[i+1,j] + img[i,j-1] + img[i,j+1])/20.0
  #return img
  #%timeit blur(img)
  #blur(img) 

#img = cv2.imread("white rose.jpg")
#img1 = img.copy()
#cv2_imshow(img1)
##blur = cv2.blur(img,(15,10))
##imgDisp = np.concatenate((img, blur), axis=1)
##cv2_imshow(imgDisp)
##s, sketch = cv2.pencilSketch(img, shade_factor = 0.04)
#styled = cv2.stylization(img, sigma_s=100, sigma_r=0.7)
#imgDisp = np.concatenate((img, styled), axis=1)
#cv2_imshow(imgDisp)
#-----------------------------------
#fig = plt.figure(figsize=(1,1))
#blur = cv2.blur(img,(15,10))
##s, sketch = cv2.pencilSketch(img, shade_factor = 0.07)
##styled = cv2.stylization(img, sigma_s=100, sigma_r=0.4)

#imgDisp = np.concatenate((img, blur, sketch, styled), axis=1)
#imgDisp = np.concatenate((img, blur), axis=1)
#cv2_imshow(imgDisp)
##plt.imshow(s, cmap="gray")

#def blur(img1):
 # img = cv2.imread("white rose.jpg")
  #blur = cv2.blur(img,(15,10))
  #imgDisp = np.concatenate((img, blur), axis=5)
  #cv2_imshow(imgDisp)
  #return img
#def pencilSketch(img1):
 # img = cv2.imread("white rose.jpg")
  #s, sketch = cv2.pencilSketch(img, shade_factor = 0.07)
  #imgDisp = np.concatenate((img, sketch), axis=1)
  #cv2_imshow(imgDisp)
  #return img
#def blend(img1):
 # img = cv2.imread("white rose.jpg")
  #styled = cv2.stylization(img, sigma_s=100, sigma_r=0.2)
  #imgDisp = np.concatenate((img, styled), axis=1)
  #cv2_imshow(imgDisp)
  #return img

img1= cv2.imread("2 kitty.webp")
img = img1.copy()
styled = cv2.stylization(img, sigma_s=100, sigma_r=0.05)
imgDisp = np.concatenate(( img,styled), axis=1)
#cv2_imshow(imgDisp)
cv2.resize(img, (100,100))
img_45 = cv2.resize(imgDisp, None, fx = 0.550, fy = 0.550)
cv2_imshow(img_45)#
# Out:
# <PIL.Image.Image image mode=RGB size=429x154 at 0x7FBA09B5F190>

# %%
img = img1.copy()
s, sketch = cv2.pencilSketch(img, shade_factor = 0.06)
imgDisp = np.concatenate((img, sketch), axis=1)
#cv2_imshow(imgDisp)
cv2.resize(img, (100,100))
img_45 = cv2.resize(imgDisp, None, fx = 0.45, fy = 0.45)
cv2_imshow(img_45)
# Out:
# <PIL.Image.Image image mode=RGB size=450x225 at 0x7FB9E963AE80>
